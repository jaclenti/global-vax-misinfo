# %% [markdown]
# # Find Location
# In this notebook we create a function to geolocate a string.
# Twitter users can give a location in their description.
# We associate the string they give with real location, to know the country they come from.
#
# Users can give any fancy location, so we need to exclude fancy names from our data to avoid mismatch such as 'my town' -> Town, Saint Lucia.
#
# Moreover, we exclude all part of text that are not locations, such as numbers, links, stopwords.

# %%
import pandas as pd
import json
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer

# %%
#list of fancy substrings that often cause mismatches in the geolocation
strange_places = []
with open("/home/jlenti/Codes/strange_places.txt","r") as f:
    for line in f:
        line = line.strip()
        strange_places.append(line)

#same list
strange_places =  ["he", "his","she","her","they","them","none","null","na","nan","secret","zone",
                   "hell","landing","rainbow","south","north","east","west","southeast","northeast",
                   "southwest","northwest","southern","northern","eastern","western","southeastern","northeastern",
                   "southwestern","northwestern","se","ne","sw","nw","earth","venus", "flat", "satan", 
                   "evil", "devil", "god", "jesus", "end", "mars", "blue", "moon",
                   "happy", "star", "war", "home", "earth", "en", "blm", "sua", "suo", "area", "university",
                   "cr", "ela", "terra", "cali", "capital", "street", "arg", "way", "galaxy", "le",
                   "casa", "maison", "house", "sun", "juno", "paradise", "dark", "hope", "valley", "deep",
                   "center", "centre", "side", "place", "hell", "heaven", "universe", "land", "northern",
                   "southern", "western", "eastern", "plain", "go", "ct", "nation", "dont", "stan",
                   "universo", "11", "kingdom", "et", "ph", "reading", "cama", "hospital", "calle",
                   "baby", "rep", "village", "metro", "disney", "club", "im", "atlantis", "tree",
                   "nord", "ovest", "est", "sud", "lua","twin","corazon","cosmos","still","camp","black",
                   "research","ave", "lakes","central","di","perk","deus","valhalla","national","dm",
                   "garden","freedom", "centro", "cpx", "teu","este","Αττική","org","earth","gru", "tn",
                   "republic", "eu", "www", "com", "gab", "park", "puta", "middle", "north", "south",
                   "west", "east", "tu", "cu", "ande", "onde", "mind", "love", "un", "villa","red","ac",
                   "union","coast","time","europa","ai", "ro","day","kl","ilha","rsa","vila", "du",
                   "hai","globe","cal","marte","oz","dot", "jupiter","top","green","ur","baker","bay",
                   "frc","cloud","jhb","sky","wall","oeste", "occidental", "falcon","sic","ops",
                   "ish","oto","school","outer","army","patriot", "uai","nova","au","peace",
                   "castle","fim","gulf coast","gulf","heart","côte","front","tower","ass","bunker",
                   "ocean","vale","real","provence","barra","beatriz","chornobyl","chernobyl",
                   "paradis","infierno","el infierno","parte","chaos","golf","ramos","comuna","angel",
                   "daniel", "candy","far","restaurant","cielo", "costa","Los Sueños", "chicken",
                   "saints", "abajo", "coral","core","viento","alice","first","estate","jaz",
                   "pianeta","twilight","avon", "pacífico", "la cara","el sur","plane","basi",
                   "field", "festà", "hub","rotten","lado","plant","el corazón","corazón","elle","canto",
                   "hanging","rua","dema","alto","auto","fucking","interior","liz","lives",
                   "mitten","kimberley", "lord", "mail","sunnydale","apex","brave","zu", "disco",
                   "universidad","600","piloto","cara","group","liga","branco","agua","weed","aries",
                   "lickely","entra","du", "promised land","feder","eccles","vive","misery","anna",
                   "cares", "el sol", "sol", "superior","sauna","pode","gravity","ole","magma",
                   "municipio","africa","asia","ponte","finger","campus","belt","troll","belong",
                   "industrial","sure","circle","lados","cis","lodge","liberal","utopia","police",
                   "bubble","federa","stranger","orion","luna","la luna","von","maya","aus","false","no name",
                   "ku","spread","main","ki","grid","hometown","grace","mal","tudo","sweet home","friends",
                   "kamino","camino","bethlehem","minor","libre","else","quarto","mansion","strong",
                   "treasure","sky","book","course","conta","golden city","la patria","nog","pais",
                   "lov","sloan","court","arena","santa","erre","isles","ranch","ville","luna","welcome","pals",
                   "bath", "dos", "bed", "beach", "fan", "gotham", "road", "via", "tlc", "hole","river",
                   "gone","troy","neo","mons","mont","alley","big","justice","train","low","big",
                   "line","curva","mtl","ddd","seca","land of oz","alone","cal","look","vaal","mama","nea","sur",
                   "aqui","alla","donald","time","chalé","boca","naast","pink","eye","justin",
                   "cave", "see","base","martha","mer","neptune","Colony","amor","hills","mile","mile high city",
                   "lead","ball","vida","lot","ball","made","phone","bairro","till","redondo","eua",
                   "post","op","sale","uai","porra","idk","ton","isle","sad","arab","triangle","springs",
                   "sei","college","plan","plana","bad","care","light","cac","leste","esp","quinto","casino",
                   "feliz","isla","loren","ward","grand","pond","ans","ad","empire","dog","mid","isola",
                   "gt","granada","south central","gran","rva","atx","hard","leo","ever","carmen",
                   "des","der","shi","hot","shore","dei","trent","cone","dome","ali","tell","linares",
                   "libertad","ile","ile-de-france","chair","alene","mountain","vc","turn","name",
                   "nice","bp","ts","coast","bm","lv","praia","madriz","ask","vv","si","tour","lu",
                   "live", "user", "ig", "tw", "back", "never", "lol", "mine", "town", "village", "piedmont",
                   "minha casa", "ماتيرا", "إيطاليا","ng","sovereign","carrera","catalana","puta","contre",
                   "mandela", "pas","station","sunday","cell","dove","atlantida","pale","ile de france","cb",
                   "pt","bs","ela","elu"
                  ]

# %%
#locdictionary associate each word to the list of location (geonameid) it can be associated to
locdictionary = json.load(open("/home/jlenti/Codes-cp/geonameslocator/locdictionary.json"))
locdictionary
# Out:
# {' lungsod ng olongapo': [1697172],
#  ' naʿwrt\u200e': [294099],
#  ' the commons': [2965243],
#  ' ناعورة\u200e': [294099],
#  ' သာယာဝတ': [11154303],
#  ' သာယာဝတီ': [11154303],
#  '1 bezirk': [11746594],
#  '1 de mayo': [3840276],
#  '1 decembrie': [664644, 856315],
#  '1 wiener gemeindebezirk': [2775259],
#  '10 de abril': [8859815,
#   8859815,
#   8871951,
#   8871951,
#   8872906,
#   8872906,
#   8886385,
#   8886385],
#  '10 de marzo': [8877742, 8877742],
#  '10 wiener gemeindebezirk': [2779776],
#  '100 mile house': [5881639],
#  '101 laid': [6697610],
#  '101073pnas0801507105': [2186224],
#  '105 km': [11874839, 11874839],
#  '105 км': [11874839],
#  '105ij kilometr': [11874839],
#  '105ий кілометр': [11874839],
#  '10bezirk': [2766447],
#  '10e arrondissement de budapest': [3049646],
#  '10eme arrondissement': [6618616],
#  '10ème arrondissement': [6618616],
#  '11': [654706],
#  '18 de marzo brecha 114 entre kilómetro 826 y 839': [8904651, 8904651],
#  '18 de marzo brecha 114 entre sur 73 y sur 815': [8878129, 8878129],
#  '18 de marzo brecha 116 con kilometro 99': [8911328],
#  '18 de marzo brecha 116 con kilómetro 99': [8911328, 8911328],
#  '18 de marzo brecha 116 entre kilometro 945 y 95': [8887931],
#  '18 de marzo brecha 116 entre kilómetro 945 y 95': [8887931, 8887931],
#  '18 de marzo brecha 117 con kilometro 8175': [8937440],
#  '18 de marzo brecha 117 con kilómetro 8175': [8937440, 8937440],
#  '18 de marzo brecha 118 con kilometro 89': [8907659],
#  '18 de marzo brecha 118 con kilómetro 89': [8907659, 8907659],
#  '18 de marzo brecha 120 entre sur 96 y sur 100': [8886023, 8886023],
#  '18 de marzo colonia': [8908979, 8908979],
#  '18 de marzo el tope': [8873140, 8873140],
#  '18 montagnes': [2597323],
#  '18 wiener gemeindebezirk': [2762091],
#  '18eme arrondissement': [6618624],
#  '18ème arrondissement': [6618624],
#  '19 de abril': [8874934, 8874934, 8932421, 8932421],
#  '19 de febrero de 1812': [8860388, 8860388],
#  '19 mayis': [8631699],
#  '19 mayis ilcesi': [8631699],
#  '19 mayıs': [8631699],
#  '19 mayıs i̇lçesi': [8631699],
#  '19 wiener gemeindebezirk': [2780893],
#  '1941glencove': [5539613],
#  '1941glencove ut': [5539613],
#  '1941glencove utah': [5539613],
#  '19eme arrondissement': [6618625],
#  '19ème arrondissement': [6618625],
#  '1e exloermond': [2756335],
#  '1e exloërmond': [2756335],
#  '1e otdelenie vinsovkhoza kastel': [8996523],
#  '1er arrondissement': [6618607],
#  '1ra seccion colonia villa morelos': [8869695],
#  '1ra sección colonia villa morelos': [8869695, 8869695],
#  '1ra sección de izapa': [3526661],
#  '1ra yalxex': [8869280, 8869280],
#  '1ro de enero': [8888988, 8888988],
#  '1ro de mayo': [8876180, 8876180, 8886686, 8886686],
#  '1е отделение винсовхоза кастель': [8996523],
#  '2': [124544],
#  '2 aguas': [6666133],
#  '2 de enero el norteño': [3971607],
#  '2 de mayo': [3434995, 3941451, 6379314, 6674629, 6674685, 8885975, 8885975],
#  '2 hermanos': [6394188, 8939042, 8939042],
#  '2 tajos rancho': [8918894, 8918894],
#  '2 wiener gemeindebezirk': [2772614],
#  '2 y 4': [8866847],
#  '20 de enero': [8865082, 8865082, 8892272, 8892272],
#  '20 de febrero': [8885692, 8885692],
#  '20 de mayo': [8875184, 8875184],
#  '20 de noviembre': [8862950,
#   8862950,
#   8863416,
#   8863416,
#   8865708,
#   8865708,
#   8867734,
#   8867734,
#   8869203,
#   8869203,
#   8870926,
#   8870926,
#   8873864,
#   8873864,
#   8875091,
#   8875091,
#   8878367,
#   8878367,
#   8878512,
#   8878512],
#  '20 de noviembre el morro': [8860317, 8860317],
#  '20 de noviembre tres': [8911292, 8911292],
#  '20 de octubre': [8887305, 8887305],
#  '20 wiener gemeindebezirk': [2781400],
#  '20e anniversaire doctobre': [687796],
#  '6й переселенческий учок': [7019628],
#  '7': [134766, 8928148],
#  '7 aguas': [10297413],
#  '7 de agosto km 2': [11695255],
#  '7 de enero': [8881942, 8881942],
#  '7 de febrero': [8913177, 8913177],
#  '7 hermanos': [8916850, 8916850],
#  '7 wiener gemeindebezirk': [2770853],
#  '7e arrondissement de budapest': [3053176],
#  '7eme arrondissement': [6618613],
#  '7ème arrondissement': [6618613],
#  '8': [128231],
#  '8 de agosto': [8901753, 8901753],
#  '8 de diciembre': [8887101, 8887101],
#  '8 de septiembre': [8882563, 8882563],
#  '8 wiener gemeindebezirk': [2775027],
#  '87472605': [8286871],
#  '89 b de i': [8872904, 8872904],
#  '8bezirk': [11704364],
#  '8eme arrondissement': [6618614],
#  '8ème arrondissement': [6618614],
#  '9 de julio': [3430383, 3842871, 3842872, 3842876, 3842877, 3842881, 3842882],
#  '9 wiener gemeindebezirk': [2782729],
#  '98a robyn road orania': [11523391],
#  '9eme arrondissement': [6618615],
#  '9ème arrondissement': [6618615],
#  'a': [3131150,
#   3163608,
#   6357277,
#   6357288,
#   6357310,
#   6359179,
#   6359203,
#   6359206,
#   6359207,
#   6359821,
#   6359832,
#   6359852,
#   6359865,
#   6359876,
#   6359880,
#   6359889,
#   6359896,
#   6359899,
#   6360212,
#   6360219,
#   6360226,
#   6360258],
#  'a a ke si a er xie te ba si ka sang': [3038566],
#  'a ai er cen': [2959374],
#  'a ai rang': [6441130],
#  'a ai te ci': [3038565],
#  'a ai wei er': [6452581],
#  'a an': [3038562],
#  'a ba': [2353151],
#  'a ba bo': [3924668],
#  'a ba dan': [145459],
#  'a ba di ya qie lei tuo': [6543681],
#  'a ba er ke': [3014116],
#  'a ba ha na er qi': [2033824],
#  'a ba ka li ji': [2353099],
#  'a ba kan': [1512236],
#  'a ba la qi ke la': [4146148],
#  'a ba la qi ke la fl': [4146148],
#  'a ba la qi ke la florida': [4146148],
#  'a ba lei te': [3038799],
#  'a ba si gang': [141681],
#  'a ba zha': [1512205],
#  'a bad': [1559775],
#  'a ban kai': [3948642],
#  'a ban wei er': [3038808],
#  'a bang dai su': [3038801],
#  'a bang dai xu': [3038800],
#  'a bang dang': [3038744],
#  'a bang ku er': [6452420, 6455366, 6613159, 6613334],
#  'a baña': [3119982],
#  'a bei ao ku ta': [2352947],
#  'a bei di lei li': [2657784],
#  'a bei er re mang la long ke': [3038774],
#  'a bei er re mang lai tai xi': [6452294],
#  'a bei ku er': [3038793, 6455369],
#  'a bei la ni': [2657850],
#  'a bei ma ma huan jiao': [7521582],
#  'a bei wei er la li wei ai': [3038786],
#  'a bei wei er lai kong fu lang': [6452390],
#  'a bei xie': [245785],
#  'a bei yang': [3038782],
#  'a ben bei ge': [2959855],
#  'a ben gu lu': [2293549],
#  'a ben si bei ge': [2959842],
#  'a bertolacci': [8968778, 8968778],
#  'a bheiniseala': [3625428],
#  'a bhreatainn bheag': [3030293],
#  'a bhruaich': [2649089, 2649089],
#  'a bi di bidi mi si kan ming ge': [5881941],
#  'a bi duo': [6452452],
#  'a bi fei er': [2967095],
#  'a bi lai ke si': [2967092],
#  'a bi lin': [4267354, 4669635],
#  'a bi lin kansas': [4267354],
#  'a bi lin ks': [4267354],
#  'a bi lin texas': [4669635],
#  'a bi lin tx': [4669635],
#  'a bi rang': [2293538],
#  'a bi ren': [2293538],
#  'a bi tan': [3038766],
#  'a bi wei er': [4178992, 4829449],
#  'a bi wei er al': [4829449],
#  'a bi wei er alabama': [4829449],
#  'a bi wei er ga': [4178992],
#  'a bi wei er georgia': [4178992],
#  'a bi wei er xian': [4568959],
#  'a bi wei er xian sc': [4568959],
#  'a bi wei er xian south carolina': [4568959],
#  'a bi ya pa lu ao ya': [592626],
#  'a bi yi': [3038768],
#  'a bin deng': [4743815],
#  'a bin deng va': [4743815],
#  'a bin deng virginia': [4743815],
#  'a bin si ke': [584441],
#  'a bo': [1864902],
#  'a bo da ka': [4018390],
#  'a bo da nan': [145233],
#  'a bo dai er': [2657835],
#  'a bo de si wei er': [6284995],
#  'a bo di': [3407440],
#  'a bo ding': [2657832, 4346913, 4415813, 5225857, 5583714, 5785243],
#  'a bo ding id': [5583714],
#  'a bo ding idaho': [5583714],
#  'a bo ding jun': [2657830],
#  'a bo ding maryland': [4346913],
#  'a bo ding md': [4346913],
#  'a bo ding mississippi': [4415813],
#  'a bo ding ms': [4415813],
#  'a bo ding sd': [5225857],
#  'a bo ding south dakota': [5225857],
#  'a bo ding wa': [5785243],
#  'a bo ding washington': [5785243],
#  'a bo du li nuo': [584471],
#  'a bo e en': [3038751],
#  'a bo er da': [2955770],
#  'a bo he er': [1279403],
#  'a bo ka': [4146166],
#  'a bo ka fl': [4146166],
#  'a bo ka florida': [4146166],
#  'a bo ku er': [6455364],
#  'a bo ku er ao tai ku er': [6617061],
#  'a bo li si te wei si': [2657782],
#  'a bo ma tuo ke si xian': [4744616],
#  'a bo ma tuo ke si xian va': [4744616],
#  'a bo ma tuo ke si xian virginia': [4744616],
#  'a bo shi': [1864902],
#  'a bo si tuo luo wei': [713245],
#  'a bo wei er': [2293268],
#  'a bo wei er sheng lu xi an': [3038783],
#  'a bo wei yang': [617026],
#  'a bo yi suo': [2293507],
#  'a bonifacio': [1730789],
#  'a bu ci bei xin gen': [2959773],
#  'a bu ci ge ming de': [2959766],
#  'a bu ci wen de': [2959749],
#  'a bu dang ge': [6437555],
#  'a bu fa er te si ba he': [7872587],
#  'a bu gu': [2352778],
#  'a bu ha zi': [6643410],
#  'a bu jia': [2352778],
#  'a bu kao de': [2760067],
#  'a bu kui ji': [5454711],
#  'a bu kui ji new mexico': [5454711],
#  'a bu kui ji nm': [5454711],
#  'a bu lai re': [3038759],
#  'a bu lan ku er pu lei su wa er': [3038764],
#  'a bu lan sheng na ze er': [3038763],
#  'a bu lan te shen': [2272447],
#  'a bu lan wei er': [6436645],
#  'a bu lan ze wei er': [3038762],
#  'a bu lang ku er': [3038761],
#  'a bu lei shen wei lai': [3038738],
#  'a bu lei si': [3038735],
#  'a bu lei wu ai li ma': [3408404],
#  'a bu li': [3038756],
#  'a bu li ke suo wei': [10048833],
#  'a bu lie': [3038734],
#  'a bu long': [3038755],
#  'a bu lu de': [686712],
#  'a bu lu zuo': [3183560],
#  'a bu luo si': [2657215],
#  'a bu luo wei er': [6439111],
#  'a bu nan': [6452203],
#  'a bu sang': [6441450],
#  'a bu si bei ge': [2959803],
#  'a bu si ta te': [2959793],
#  'a bu te wei er': [7285017],
#  'a bu te wei lei': [2959747],
#  'a bu wei er': [3038789, 4314295, 4568985],
#  'a bu wei er la': [4314295],
#  'a bu wei er louisiana': [4314295],
#  'a bu wei er sc': [4568985],
#  'a bu wei er south carolina': [4568985],
#  'a bu zha bi': [292968],
#  'a bu zha ke': [6452155, 6452259],
#  'a bustarga': [3127409],
#  'a can gjinh argentina': [3865483],
#  'a cang bu er': [6437581],
#  'a capela': [6357288],
#  'a casa da eira': [7115505],
#  'a casalta dampugnani': [3028478],
#  'a castellanos': [3867050],
#  'a ce si bei ge': [2782273],
#  'a ceive de soei': [3170739],
#  'a ceive de söi': [3170739],
#  'a cha ka qi': [3924610],
#  'a chairtbheil': [614540],
#  'a che cheng': [4671174],
#  'a che cheng texas': [4671174],
#  'a che cheng tx': [4671174],
#  'a che xian': [4671180],
#  'a che xian texas': [4671180],
#  'a che xian tx': [4671180],
#  'a cheinia': [192950],
#  'a chen': [3247449],
#  'a cheng': [2038678, 2038679],
#  'a cheng shi': [2038678, 2038679],
#  'a chuimrigh': [2634895],
#  'a ci bu lu ke': [3013619],
#  'a coruna': [3119840, 3119841, 6357300],
#  'a coruña': [3119840, 3119841, 3119841, 6357300, 6357300],
#  'a costa': [3177890, 6616391],
#  'a croce dampugnani': [6616392],
#  'a croxe': [3177781],
#  'a crucichja': [3022405],
#  'a cruna': [3119841],
#  'a cruña': [3119841],
#  'a còsta': [3177890],
#  'a da er wei er': [4282213],
#  'a da er wei er kentucky': [4282213],
#  'a da er wei er ky': [4282213],
#  'a da mi fu ka': [713806],
#  'a da mo fu': [3079841],
#  'a da na': [325363],
#  'a da na sheng': [325361],
#  'a da nei luo': [3130958],
#  'a da pa zha lei': [752850],
#  'a da si': [3038666],
#  'a dai': [6452458],
#  'a dai er': [4846398],
#  'a dai er ia': [4846398],
#  'a dai er iowa': [4846398],
#  'a dai er wei ye er pu xie er gai': [3038661],
#  'a dan': [6450250],
#  'a dan fu': [3038659],
#  'a dan ku er': [6452411],
#  'a dang ku er laiao ke luo she': [3014098],
#  'a dang lai pa sa wang': [6452206],
#  'a dang si wei lai': [3038668],
#  'a de er': [3037113],
#  'a de er bei ge': [2959553],
#  'a de er bo deng': [2661863],
#  'a de er ci hao sen': [2959492],
#  'a de er hai ci duo fu': [2959538],
#  'a de er ke fen': [2959422],
#  'a de er man si fei er deng': [2959530],
#  'a de er si duo fu': [6556862],
#  'a de er si hai mu': [2959508],
#  'a de er si li de': [2959498],
#  'a de er wang': [2782980],
#  'a de he': [2522437],
#  'a de la': [6355520],
#  'a de la da si': [3130940],
#  'a de la er': [2508813],
#  'a de la er sheng': [2381972],
#  'a de lai bu sen': [2959548],
#  'a de lai de': [2078025],
#  'a de lan tuo': [5322400],
#  'a de lan tuo ca': [5322400],
#  'a de lan tuo california': [5322400],
#  'a de li gen si wei er': [2661862],
#  'a de li si wei er': [2661861],
#  'a de li ye': [3038654],
#  'a de lie er': [584243],
#  'a de meng te': [2782979],
#  'a de mu si': [3130950],
#  'a de nao': [2959489],
#  'a de nei te': [2782976],
#  'a de ya man': [325330],
#  'a de ya man sheng': [325330],
#  'a deng': [2661725],
#  'a deng ba he': [2959486],
#  'a deng bi te er': [2959482],
#  'a deng duo fu': [2959479],
#  'a deng si te': [2959475],
#  'a di': [6449516, 6450249, 6455275],
#  'a di an wei er': [3036467],
#  'a di ao si': [3130946],
#  'a di ba ya': [3471335],
#  'a di en sa': [3129197],
#  'a di ge wei er': [3036447],
#  'a di jia si': [3443758],
#  'a di jia si sheng': [3443756],
#  'a di na': [6538702],
#  'a di ni': [3036444, 6446793, 6451757],
#  'a di ni ya': [6454897],
#  'a di sang': [3038658],
#  'a di sen xian': [5233146],
#  'a di sen xian vermont': [5233146],
#  'a di sen xian vt': [5233146],
#  'a di shen': [6455195],
#  'a di si a bei ba': [344979],
#  'a di si meng si': [3036460],
#  'a di si wei er': [2661692],
#  'a di su lang': [6446444],
#  'a di xi': [3036450],
#  'a di xi ya': [5324862],
#  'a di xi ya ca': [5324862],
#  'a di xi ya california': [5324862],
#  'a di ye': [6617913],
#  'a di ye de qu wei lai er': [2968399],
#  'a di yi': [6446445],
#  'a dong': [6452332],
#  'a dos cunhados': [2272379, 2272379, 8012562],
#  'a dos francos': [2272378, 2272378, 8012339],
#  'a dos negros': [8012385],
#  'a du er he pan ge lei na de': [3014744],
#  'a du he pan ke zha ke': [6616503],
#  'a du he pan pu lei sha ke': [6432067],
#  'a du he pan sheng mo li ke': [6433968],
#  'a duo': [3014096],
#  'a duo fu': [2661882, 2959390, 6550760],
#  'a en fu er si': [2782410],
#  'a en shi ta te': [2955439],
#  'a en si bei ge': [2955471],
#  'a en si bei ke': [2959150],
#  'a er': [6424455, 6448825, 6614078],
#  'a er a ma de ge la na da': [2521993],
#  'a er a ma de mu er xi ya': [2521992],
#  'a er a ma de ya er mei li ya': [2521994],
#  'a er a ma he pan sai er wei la de er': [3125297],
#  'a er ao li nei er ge lan de': [2521985],
#  'a er ao lin de la tuo lei': [2521986, 6359412],
#  'a er ba': [3038285, 6448241, 6452337, 6539323, 6540671],
#  'a er ba gu la': [6539353],
#  'a er ba ke xiang': [686580],
#  'a er ba la luo man': [3038302],
#  'a er ba lei duo a er na bo er di': [6542784],
#  'a er ba lei lei kong ta': [6452350],
#  'a er ba lei sheng ma li': [6452351],
#  'a er ba lei tuo': [6538418],
#  'a er ba lei tuo de la tuo lei': [6543276],
#  'a er ba na te': [3037311],
#  'a er ba nei la': [6542064],
#  'a er ba ni ya': [783754],
#  'a er ba nuo wei qie lai sai': [6539534],
#  'a er ba xing': [2958756],
#  'a er ba you li ya': [686578],
#  'a er ban': [6452545],
#  'a er bang': [2661731, 3037282, 3037303, 6455355, 6455376],
#  'a er bao': [2661879],
#  'a er bei': [3038271, 6451270],
#  'a er bei ao si': [3037302],
#  'a er bei ba he': [3323982],
#  'a er bei er ci huo fen': [2958653],
#  'a er bei ge': [2661880, 2955697],
#  'a er bei ke': [2782843],
#  'a er bei la te xi lai gai': [3037301],
#  'a er bei luo bei luo': [3183330],
#  'a er bei sai lei': [3037267],
#  'a er bei sen': [2958641],
#  'a er bei shi wen de': [8299680],
#  'a er bei si ba he': [2782443],
#  'a er bei si te luo': [6449875],
#  'a er bei te si long zi zhi shi': [2624906],
#  'a er bei tuo nei': [6538250],
#  'a er bei wei er': [3038266],
#  'a er bi': [3037265, 3037295, 3038261, 6452264],
#  'a er bi a': [6452549],
#  'a er bi a ke': [6616457],
#  'a er bi ni': [6446367],
#  'a er bi ni e': [6446366],
#  'a er bi ni ya ke': [3038251],
#  'a er bi nuo': [6540342],
#  'a er bi sa ke': [6452173],
#  'a er bi si fu jin a fu er te en': [2661842],
#  'a er bi si fu jin lang nao': [6640317],
#  'a er bi xi': [2958638],
#  'a er bi ya nuo': [6540225],
#  'a er bi ye': [6452112],
#  'a er bi ye sang': [6452598],
#  'a er bi zha tai': [6536476],
#  'a er bin': [7873169],
#  'a er bo': [6449580],
#  'a er bo jia': [2725471],
#  'a er bo la': [6448446],
#  'a er bo lei ya': [6539884],
#  'a er bo li ao': [6538098],
#  'a er bo ma er xian': [4744031],
#  'a er bo ma er xian va': [4744031],
#  'a er bo ma er xian virginia': [4744031],
#  'a er bo nei sai': [6540623],
#  'a er bo ni ye er': [3013955],
#  'a er bo pi ye er bu lei dong': [3038274, 6447247],
#  'a er bo si duo fu': [6551297],
#  'a er bo si hao sen': [2958707],
#  'a er bo si wei er': [2661829],
#  'a er bo si wei lei': [2958696],
#  'a er bu ai xu suo te': [3037275],
#  'a er bu ang': [6447811],
#  'a er bu er si': [6614063],
#  'a er bu fei la': [8010512],
#  'a er bu he de qu shi tai yin hai mu': [2827989],
#  'a er bu ka fu': [6452302],
#  'a er bu la de lai ao': [6452256],
#  'a er bu la de lai ba': [6452255],
#  'a er bu la se dan': [2759915],
#  'a er bu lu ke': [2958744, 3207679],
#  'a er bu si': [6539273],
#  'a er bu si ta te': [2958595],
#  'a er bu suo er': [3037271, 6452466],
#  'a er bu wa': [3037287],
#  'a er bu xi ai': [6452104],
#  'a er bu zha nuo': [3183306],
#  'a er cang': [3036604],
#  'a er cang ao': [6452228],
#  'a er cang bu yi': [6449955],
#  'a er cang ke de lang dong': [6452356],
#  'a er ci ba he': [2955376],
#  'a er ci fei er de': [2955363],
#  'a er ci hao sen': [2956847],
#  'a er ci he pan bu ge ji xing': [2941216],
#  'a er ci wei lai': [6449894],
#  'a er da han': [751952],
#  'a er da han sheng': [862470],
#  'a er da la': [6541352],
#  'a er da tuo fu': [581187],
#  'a er dai': [6617307],
#  'a er dai a': [6361886],
#  'a er dai ya': [3182897],
#  'a er dan gang': [3013935],
#  'a er dan si ji qu': [2027964],
#  'a er dan wa si': [3013934],
#  'a er dang ge si': [6450442],
#  'a er dang ku er': [6445589],
#  'a er dang re': [6436408],
#  'a er dang tai': [3037133],
#  'a er dao li': [6537960],
#  'a er de bei er en': [2958036],
#  'a er de ci': [2661726],
#  'a er de er si ba he': [2958577],
#  'a er de ku er ou bu wa': [6444521],
#  'a er de lan si': [2782813],
#  'a er de nai': [6614076],
#  'a er de wei la de ai er te si': [3130450],
#  'a er de ya da wei la de la li wei la': [3130529],
#  'a er de ya er bo suo': [3130502],
#  'a er de ya la feng te': [3130511],
#  'a er de yi he meng fu ke sai lei': [6446789],
#  'a er deng': [2959237],
#  'a er deng huo fen': [2958580],
#  'a er di': [3036646, 6450397],
#  'a er di bi he pan kong pu': [3024051],
#  'a er di dai': [3038233],
#  'a er di e er': [6452353],
#  'a er di fu er': [6438274],
#  'a er di gai': [6455042, 6618240],
#  'a er di gai lu fu': [3036663],
#  'a er di gai lu tang': [3036664],
#  'a er di gai mi': [6450451],
#  'a er di gai pu lei bo er duo': [3036655],
#  'a er di jia': [6446851],
#  'a er di la ke': [3038013],
#  'a er di li ai': [3037125],
#  'a er di li ya': [6539844],
#  'a er di nuo': [733638, 6536004, 6541224],
#  'a er di te': [2957108],
#  'a er di teng duo fu': [2957103],
#  'a er di wei lai er': [3013932],
#  'a er di wo lai': [6543002],
#  'a er di xi mo': [6542988],
#  'a er di ye': [3036682],
#  'a er di ye de qu sheng xi': [2980954],
#  'a er ding gen': [2958575],
#  'a er dong': [581179, 6448763, 6452335],
#  'a er du de': [686206],
#  'a er du wa': [3037121],
#  'a er duo lei': [6539857],
#  'a er duo ye': [2803092],
#  'a er en bu lu ke': [2955527],
#  'a er en lei te': [2782406],
#  'a er en shi wang': [2955464],
#  'a er en si tai yin': [6558390],
#  'a er en si tuo er fu': [2955429],
#  'a er fa er pu': [2522047],
#  'a er fa fa er': [2522057],
#  'a er fa luo': [6359001],
#  'a er fei er de': [2958533],
#  'a er fei na si': [3472603],
#  'a er fei si luo hei': [2956729],
#  'a er fei ya nuo na ta': [6536431],
#  'a er feng': [6451340],
#  'a er fu': [2958539],
#  'a er fu duo fu': [2958535],
#  'a er fu hao sen': [2958523],
#  'a er fu ling e mu': [2803252, 2803253],
#  'a er fu lun': [2958522],
#  'a er fu si dun': [2635183],
#  'a er fu te': [2958516],
#  'a er fu wei er': [3038213],
#  'a er fu yi er sha tan': [6452194],
#  'a er fu yi lai': [3037082, 6613322],
#  'a er fu yi lai sheng pu li ye si': [3036810],
#  'a er gai': [6447817],
#  'a er gai nong he pan pu luo lei ke': [6429063],
#  'a er gai nuo': [6448244],
#  'a er gan sa': [6358558],
#  'a er gan su ai la': [6544487],
#  'a er gang': [3038206],
#  'a er gang he pan luo qu ai bu lu na': [2982875],
#  'a er gang he pan meng te fu er': [2992583],
#  'a er gang he pan pi re': [2985143],
#  'a er gang song': [3037076],
#  'a er gang te nai': [6451819],
#  'a er gang xi': [3037075, 6447178],
#  'a er gao de qu wang gen': [2814270],
#  'a er ge': [4830478, 6452227],
#  'a er ge al': [4830478],
#  'a er ge alabama': [4830478],
#  'a er ge da si': [3129588],
#  'a er ge er fa': [2522001],
#  'a er ge er mi sen': [2958509],
#  'a er ge er sang': [6452474],
#  'a er ge fu': [6614454],
#  'a er ge he pan sha ze': [3025663],
#  'a er ge na ke': [4983970],
#  'a er ge na ke mi': [4983970],
#  'a er ge na ke michigan': [4983970],
#  'a er ge ni ao si': [3129593],
#  'a er ge ni ya': [2521999],
#  'a er ge si': [264670],
#  'a er ge yi de qu luo yi te ji xi': [2878270],
#  'a er ge yi de qu yi si ni': [2895638],
#  'a er gen shi wang': [2955610],
#  'a er gen ta er': [2955605],
#  'a er gong': [581126],
#  'a er gu re': [6449450],
#  'a er gu si tuo': [6541750],
#  'a er gui luo': [6543808],
#  'a er ha ming': [2782784],
#  'a er hai mu': [2958494],
#  'a er he': [2661729],
#  'a er he mei xi': [2522012],
#  'a er he xi la si': [2522013],
#  'a er heng si suo la': [6356044],
#  'a er heng tuo na': [6356045],
#  'a er huo na': [2521594],
#  'a er ji': [3036970, 6452284, 6540014],
#  'a er ji er': [2507480],
#  'a er ji li': [6447562],
#  'a er ji li ya': [2589581],
#  'a er ji li ye er': [3036999],
#  'a er ji ne': [6450234],
#  'a er ji ye': [2661703],
#  'a er jia er': [6356918],
#  'a er jia er tang ao mi nei': [6437569],
#  'a er jia luo wo': [6359410],
#  'a er jia ni weng': [3037080],
#  'a er jie la tuo': [6536737],
#  'a er jie ni ao': [6540575],
#  'a er jie si tuo wei': [713135],
#  'a er jie xian': [4983956],
#  'a er jie xian mi': [4983956],
#  'a er jie xian michigan': [4983956],
#  'a er ka da ke': [581080],
#  'a er ka de': [6538292],
#  'a er ka la de ke xi wei er te': [6356963],
#  'a er ka la la lei ya er': [2522160],
#  'a er ka la li': [2522159],
#  'a er ka la li fu xi': [6539144],
#  'a er ka la sai huo si': [2522146],
#  'a er ka lei ke': [1526193],
#  'a er ka na de lei': [3130610],
#  'a er ka nei na': [2272189],
#  'a er ka ni yi sai si': [3130607],
#  'a er ka ni yi si': [3130606],
#  'a er ka sa er de sheng hu an': [2522131],
#  'a er ka xiong': [3037253],
#  'a er kai fu': [6451278],
#  'a er kan ta la': [2522155],
#  'a er kan ta li li ya': [6359510],
#  'a er kang ba': [6452341],
#  'a er kang gai': [3037245],
#  'a er kao de te': [6358458],
#  'a er ke': [6539794, 6618443],
#  'a er ke ba sa': [2272147, 8012306],
#  'a er ke er kong': [3130564],
#  'a er ke er si lai ben': [2958480],
#  'a er ke er su mu': [6551525],
#  'a er ke he pan bi ke xi ai': [6446951],
#  'a er mang di e': [6452258],
#  'a er mang di ye er': [3036903],
#  'a er mang ku er': [6617725],
#  'a er mang song he pan bu li ye nong': [3030090],
#  'a er mang song he pan meng di ni': [6428760],
#  'a er mang song he pan pa xi': [2988849],
#  'a er mang song he pan xie li': [6428524],
#  'a er mang te er': [6450445],
#  'a er mei da': [8012053],
#  'a er mei er si ba he': [2958235],
#  'a er mei li ya': [2521886],
#  'a er mei li ya sheng': [2521883],
#  'a er mei na er de suo li ya': [3130303],
#  'a er mei na la': [3472520],
#  'a er mei nei xie': [6452433],
#  'a er mei nuo': [6538122],
#  'a er men de la': [6362999],
#  'a er men de la er': [2521894],
#  'a er men de la lai huo': [2521893],
#  'a er meng gu': [6537887],
#  'a er meng lai rui nie': [6615860],
#  'a er meng te': [2521857],
#  'a er mi': [6446369],
#  'a er mi lan te ta man da lei': [3472518],
#  'a er mi li ya': [2521590],
#  'a er mi sang': [3036893],
#  'a er mo': [6451821],
#  'a er mo ku er': [6449691],
#  'a er mo la': [1278974],
#  'a er mo la di': [2521855],
#  'a er mo la xian': [1278975],
#  'a er mo na si te er la lei ya er': [6358180],
#  'a er mo si ba he': [2958288],
#  'a er mu he ke': [6613277],
#  'a er mu nie ka er': [2521847],
#  'a er mu si hai mu': [2955542],
#  'a er na ke': [6447236],
#  'a er na ke la bo si te': [3036879],
#  'a er na ke peng pa du': [3036878, 6447486],
#  'a er na wei er': [6449692],
#  'a er nai lai di ke': [3036862],
#  'a er nai su wei tuo': [6447564],
#  'a er nai weng': [6424406],
#  'a er ne': [3013908],
#  'a er nei bao': [2955519],
#  'a er nei di e': [3129477],
#  'a er nei duo': [3129476],
#  'a er nei ji': [3036857],
#  'a er nei ke': [6450025],
#  'a er nei si': [2657445],
#  'a er ni': [6438275],
#  'a er ni ku er': [6446790],
#  'a er ni si': [7602476],
#  'a er nie': [6425969],
#  'a er nong he pan lu li': [6428210],
#  'a er nong he pan lu wa ai': [6428206],
#  'a er nong he pan ma lei yi': [6428213],
#  'a er nong he pan sheng ruo er re': [2979894],
#  'a er nuo': [3036847],
#  'a er pa rong': [3036823],
#  'a er pa weng': [6447865],
#  'a er pai': [5770732],
#  'a er pai en': [5817073],
#  'a er pai en wy': [5817073],
#  ...}

# %%
len(locdictionary)
# Out:
# 1887100

# %%
#dataframe with all location we can geolocate, and relative country
#we also need the population, because if a string is associated two locations, we choose the most populated one
locationdata = pd.read_csv("/home/jlenti/Codes-cp/geonameslocator/countriesdatap.tsv", sep = '\t', low_memory = False,
                           index_col = "geonameid").drop([2855707, 2769324])
locationdata.head()
# Out:
#                              name               asciiname  \
# geonameid
# 290557       United Arab Emirates    United Arab Emirates
# 290594         Umm Al Quwain City      Umm Al Quwain City
# 290595      Imārat Umm al Qaywayn   Imarat Umm al Qaywayn
# 291074        Ras Al Khaimah City     Ras Al Khaimah City
# 291075     Imārat Ra’s al Khaymah  Imarat Ra's al Khaymah
#
#                                               alternatenames  latitude  \
# geonameid
# 290557     ['United Arab Emirates', "'Alepea Fakatahataha...  23.75000
# 290594     ['Umm Al Quwain City', 'Oumm al Qaiwain', 'Oum...  25.56473
# 290595     ['Imārat Umm al Qaywayn', 'Imarat Umm al Qaywa...  25.50000
# 291074     ['Ras Al Khaimah City', 'Julfa', 'Khaimah', 'R...  25.78953
# 291075     ['Imārat Ra’s al Khaymah', "Imarat Ra's al Kha...  25.66667
#
#            longitude featureclass featurecode countrycode  cc2 admin1code  \
# geonameid
# 290557      54.50000            A        PCLI          AE  NaN        0.0
# 290594      55.55517            P        PPLA          AE  NaN        7.0
# 290595      55.75000            A        ADM1          AE  NaN        7.0
# 291074      55.94320            P        PPLA          AE  NaN        5.0
# 291075      56.00000            A        ADM1          AE  NaN        5.0
#
#           admin2code admin3code admin4code  population  elevation  dem  \
# geonameid
# 290557           NaN        NaN        NaN     9630959        NaN   96
# 290594           NaN        NaN        NaN       62747        NaN    2
# 290595           NaN        NaN        NaN       56253        NaN   52
# 291074           NaN        NaN        NaN      351943        NaN    2
# 291075           NaN        NaN        NaN      187535        NaN   18
#
#              timezone modificationdate
# geonameid
# 290557     Asia/Dubai       2020-03-29
# 290594     Asia/Dubai       2019-10-24
# 290595     Asia/Dubai       2020-07-08
# 291074     Asia/Dubai       2019-09-09
# 291075     Asia/Dubai       2020-07-08

# %%
len(locationdata)
# Out:
# 568309

# %%
#other mismatches are given by numbers or stopwords
engstopwords = stopwords.words("english")
esstopwords = stopwords.words("spanish")
ptstopwords = stopwords.words("portuguese")

numbers = {'zero','one','two','three','four','five','six','seven','eight','nine','ten',
           'eleven','twelve','thirteen','fourteen','fifteen','sixteen','seventeen','eighteen',
           'nineteen','twenty','thirty','fourty','fifty','sixty','seventy','eighty','ninety',
           'hundred','thousand','million','billion','zillion'}

num = [str(n) for n in range(100)]

# %%
# Turn tokens into a sequence of n-grams
def word_ngrams(tokens, ngrams):
    min_n, max_n = 1, ngrams
    if max_n != 1:
        original_tokens = tokens
        tokens = []
        n_original_tokens = len(original_tokens)
        for n in range(min_n, min(max_n + 1, n_original_tokens + 1)):
            for i in range(n_original_tokens - n + 1):
                tokens.append(" ".join(original_tokens[i: i + n]))
    return tokens

#transform a string in sequences of names, to find the possible locations inside a longer string
tokenizer = RegexpTokenizer(r'\w+')
def find_names(text):
    tokens = word_ngrams(tokenizer.tokenize(text.lower()), 5)
    m = set()
    for token in tokens:
        if token in locdictionary:
            m.add(token)
    # filter out matched places that are substrings of another matched place
    k_list = list(m)
    for i, k in enumerate(k_list):
        for k2 in k_list[:i]:
            if k in k2 and k in m:
                m.remove(k)
        for k2 in k_list[i+1:]:
            if k in k2 and k in m:
                m.remove(k)
    return m

# Finds the best match for the text
# For speed reasons, returns only the geonamesid which can be used to index into countriesdatap
def find_best_match(text):
    #correct common mismatches
    if "Ile-de-France" in text:
        text = "Paris"
    if "Repùblica Catalana" in text:
        text = "Barcelona"
    if ("Buenos Aire" in text)|("Castelar" in text):
        text = "Buenos Aires"
    if "Islamabad" in text:
        text = "Pakistan"
    if "Brasi" in text:
        text = "Brasil"
    mymatches = find_names(text)
    #if mymatches:
    # Try finding all the matches
    bestmatch = None
    matcharray = []
    matchedids = []
    foundcountry = None
    countrymatches = None
    # Put all the matches in one array
    for foundloc in mymatches:
        matchedids = matchedids + locdictionary[foundloc]
     #remove some bad match
    
    # If there is more than 1 match, and there is a match to a country, constrain all other matches to that country
    if len(matchedids) > 1:
        matchedlocations = locationdata.loc[matchedids]
        if pd.DataFrame.any(matchedlocations.featurecode=="PCLI"):
            foundcountry = matchedlocations[matchedlocations.featurecode=="PCLI"].iloc[0].countrycode
            countrymatches = matchedlocations[matchedlocations.countrycode==foundcountry]
    # For each word match, find the most populous one
    for foundloc in mymatches:
        # Handle special cases
        if len(foundloc) < 2:
            continue
        if (foundloc in engstopwords) | (foundloc in esstopwords) | (foundloc in ptstopwords) | (foundloc in num) | (foundloc in numbers) | (foundloc in strange_places):
            continue
        else:
            matchedlocations = locationdata.loc[locdictionary[foundloc],:]
            if foundcountry: # Remove matches that are not in the country we found
                matchedlocations = matchedlocations[matchedlocations.countrycode==foundcountry]
            if matchedlocations.shape[0] > 0:
                foundmatch = matchedlocations.sort_values(by="population",ascending=False).index[0]
                matcharray.append(foundmatch)
    # Among all the matches, find the least populous one
    if len(matcharray) > 0:
        allmatches = locationdata.loc[matcharray]
        bestmatch = allmatches.sort_values(by="population",ascending=True).index[0]
    return bestmatch

def find_location(text):
    #return [location, countrycode] if possible, otherwise [null, null]
    #if the string seems to be a link or tag return [null, null]
    if text == None:
        return["null", "null"]
    if ".com" in text:
        return ["null", "null"]
    elif "@" in text:
        return ["null", "null"]
    else:
        try:
            #extract the most populous location substring from the string
            loc_match = find_best_match(text)
            #geolocate the location from the geonameid
            location = locationdata.loc[loc_match]
            #keep only location and countrycode
            return location[["name", "countrycode"]]
        except:
            return ["null", "null"]

# %%
examples = []

for location in ["roma", "Rome", "Buenos Aires", "Abuja", "naples", "Lima, Peru", "Bloomington, Indiana, US",
                 "Indiana", "United States", "Moon", "Luna", "Antananarivo", "LOL", "my bedroom"]:
    examples.append([location, find_location(location)[0], find_location(location)[1]])

# %%
pd.DataFrame(examples, columns = ["user_location", "real_location", "user_country_code"])
# Out:
#                user_location                         real_location  \
# 0                       roma  Città metropolitana di Roma Capitale
# 1                       Rome  Città metropolitana di Roma Capitale
# 2               Buenos Aires                          Buenos Aires
# 3                      Abuja                                 Abuja
# 4                     naples                                Napoli
# 5                 Lima, Peru                                  null
# 6   Bloomington, Indiana, US                           Bloomington
# 7                    Indiana                               Indiana
# 8              United States                         United States
# 9                       Moon                                  null
# 10                      Luna                                  null
# 11              Antananarivo                          Antananarivo
# 12                       LOL                                  null
# 13                my bedroom                                  null
#
#    user_country_code
# 0                 IT
# 1                 IT
# 2                 AR
# 3                 NG
# 4                 IT
# 5               null
# 6                 US
# 7                 US
# 8                 US
# 9               null
# 10              null
# 11                MG
# 12              null
# 13              null
